# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import cifar10

# %%
# 加载 CIFAR-10 数据集
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# 数据归一化到 [0, 1]
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
# CNN 模型构建
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')  # 10个分类，输出层使用softmax激活函数
])

# %%
# 编译模型
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# 训练模型并保存 history
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
model.summary()

# 绘制损失函数和准确率曲线
plt.figure(figsize=(12, 6))

# 损失函数曲线
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Function')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# 准确率曲线
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# 评估模型并输出准确率
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001DCF6E3FAE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001DCF6E3FAE8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 782/782 [==============================] - ETA: 0s - loss: 1.5783 - accuracy: 0.4231WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001DCF6F4D400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001DCF6F4D400> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 782/782 [==============================] - 7s 7ms/step - loss: 1.5783 - accuracy: 0.4231 - val_loss: 1.3165 - val_accuracy: 0.5249
# Epoch 2/50
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2180 - accuracy: 0.5674 - val_loss: 1.1194 - val_accuracy: 0.6048
# Epoch 3/50
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0557 - accuracy: 0.6296 - val_loss: 0.9981 - val_accuracy: 0.6532
# Epoch 4/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9536 - accuracy: 0.6658 - val_loss: 0.9443 - val_accuracy: 0.6706
# Epoch 5/50
# 782/782 [==============================] - 5s 6ms/step - loss: 0.8814 - accuracy: 0.6920 - val_loss: 0.9103 - val_accuracy: 0.6858
# Epoch 6/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8167 - accuracy: 0.7135 - val_loss: 0.9763 - val_accuracy: 0.6648
# Epoch 7/50
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7640 - accuracy: 0.7326 - val_loss: 0.8757 - val_accuracy: 0.7009
# Epoch 8/50
# 782/782 [==============================] - 5s 6ms/step - loss: 0.7228 - accuracy: 0.7472 - val_loss: 0.8919 - val_accuracy: 0.7025
# Epoch 9/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6816 - accuracy: 0.7628 - val_loss: 0.8655 - val_accuracy: 0.7067
# Epoch 10/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6403 - accuracy: 0.7760 - val_loss: 0.8538 - val_accuracy: 0.7127
# Epoch 11/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.6106 - accuracy: 0.7848 - val_loss: 0.8714 - val_accuracy: 0.7153
# Epoch 12/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.5773 - accuracy: 0.7980 - val_loss: 0.8501 - val_accuracy: 0.7207
# Epoch 13/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.5427 - accuracy: 0.8077 - val_loss: 0.8451 - val_accuracy: 0.7314
# Epoch 14/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.5088 - accuracy: 0.8208 - val_loss: 0.8989 - val_accuracy: 0.7134
# Epoch 15/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.4882 - accuracy: 0.8273 - val_loss: 0.8932 - val_accuracy: 0.7188
# Epoch 16/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.4571 - accuracy: 0.8396 - val_loss: 0.9169 - val_accuracy: 0.7209
# Epoch 17/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.4292 - accuracy: 0.8486 - val_loss: 0.9609 - val_accuracy: 0.7134
# Epoch 18/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.4059 - accuracy: 0.8552 - val_loss: 0.9729 - val_accuracy: 0.7187
# Epoch 19/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3788 - accuracy: 0.8658 - val_loss: 1.0336 - val_accuracy: 0.7121
# Epoch 20/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3559 - accuracy: 0.8736 - val_loss: 1.0415 - val_accuracy: 0.7131
# Epoch 21/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3317 - accuracy: 0.8827 - val_loss: 1.0682 - val_accuracy: 0.7164
# Epoch 22/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.3081 - accuracy: 0.8916 - val_loss: 1.0820 - val_accuracy: 0.7118
# Epoch 23/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2878 - accuracy: 0.8959 - val_loss: 1.1879 - val_accuracy: 0.7063
# Epoch 24/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2717 - accuracy: 0.9035 - val_loss: 1.2086 - val_accuracy: 0.7060
# Epoch 25/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2526 - accuracy: 0.9106 - val_loss: 1.2606 - val_accuracy: 0.7062
# Epoch 26/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2385 - accuracy: 0.9146 - val_loss: 1.3152 - val_accuracy: 0.7043
# Epoch 27/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2220 - accuracy: 0.9202 - val_loss: 1.3737 - val_accuracy: 0.7078
# Epoch 28/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.2095 - accuracy: 0.9257 - val_loss: 1.4602 - val_accuracy: 0.7046
# Epoch 29/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1958 - accuracy: 0.9309 - val_loss: 1.4983 - val_accuracy: 0.6993
# Epoch 30/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1960 - accuracy: 0.9300 - val_loss: 1.5953 - val_accuracy: 0.6881
# Epoch 31/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1732 - accuracy: 0.9379 - val_loss: 1.6573 - val_accuracy: 0.6889
# Epoch 32/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1699 - accuracy: 0.9380 - val_loss: 1.6394 - val_accuracy: 0.7039
# Epoch 33/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1676 - accuracy: 0.9398 - val_loss: 1.7827 - val_accuracy: 0.6858
# Epoch 34/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1538 - accuracy: 0.9455 - val_loss: 1.7934 - val_accuracy: 0.6891
# Epoch 35/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1482 - accuracy: 0.9467 - val_loss: 1.8029 - val_accuracy: 0.6963
# Epoch 36/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1463 - accuracy: 0.9468 - val_loss: 1.8603 - val_accuracy: 0.6924
# Epoch 37/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1333 - accuracy: 0.9516 - val_loss: 1.8982 - val_accuracy: 0.6973
# Epoch 38/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1315 - accuracy: 0.9520 - val_loss: 1.9690 - val_accuracy: 0.6874
# Epoch 39/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1286 - accuracy: 0.9534 - val_loss: 2.0442 - val_accuracy: 0.6996
# Epoch 40/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1292 - accuracy: 0.9538 - val_loss: 2.0510 - val_accuracy: 0.6949
# Epoch 41/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1184 - accuracy: 0.9568 - val_loss: 2.1471 - val_accuracy: 0.6918
# Epoch 42/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1140 - accuracy: 0.9595 - val_loss: 2.2728 - val_accuracy: 0.6856
# Epoch 43/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1158 - accuracy: 0.9574 - val_loss: 2.2654 - val_accuracy: 0.6880
# Epoch 44/50
# 782/782 [==============================] - 5s 6ms/step - loss: 0.1081 - accuracy: 0.9621 - val_loss: 2.2458 - val_accuracy: 0.6956
# Epoch 45/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1239 - accuracy: 0.9569 - val_loss: 2.3362 - val_accuracy: 0.6873
# Epoch 46/50
# 782/782 [==============================] - 5s 6ms/step - loss: 0.1028 - accuracy: 0.9634 - val_loss: 2.3639 - val_accuracy: 0.6937
# Epoch 47/50
# 782/782 [==============================] - 4s 6ms/step - loss: 0.1050 - accuracy: 0.9630 - val_loss: 2.4297 - val_accuracy: 0.6931
# Epoch 48/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1097 - accuracy: 0.9607 - val_loss: 2.4490 - val_accuracy: 0.6896
# Epoch 49/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.0929 - accuracy: 0.9663 - val_loss: 2.5143 - val_accuracy: 0.6908
# Epoch 50/50
# 782/782 [==============================] - 4s 5ms/step - loss: 0.1022 - accuracy: 0.9643 - val_loss: 2.4941 - val_accuracy: 0.6859
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4941 - accuracy: 0.6859
# Test accuracy: 0.6858999729156494

# %%
num_images = 5
predictions = model.predict(X_test[:num_images])
predicted_classes = np.argmax(predictions, axis=1)

# CIFAR-10 类别标签
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# 显示图像与预测结果
plt.figure(figsize=(10, 5))
for i in range(num_images):
    plt.subplot(1, num_images, i + 1)
    plt.imshow(X_test[i])
    plt.title(f"Pred: {class_names[predicted_classes[i]]}")
    plt.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001DCFDC036A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001DCFDC036A8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
